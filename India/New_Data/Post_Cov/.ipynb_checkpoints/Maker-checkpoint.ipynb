# %%
import pandas as pd
import numpy as np
import json
from datetime import date
import calendar
import networkx as nx


TS=date(2021,1,1)
TE=date(2021,3,1)




dic_month={"Jan":1,"Feb":2,"Mar":3,"Apr":4,"May":5,"Jun":6,"Jul":7,"Aug":8,"Sep":9,"Oct":10,"Nov":11,"Dec":12}
df2=pd.read_excel("INDIA.XLSX")
dic={}
df2
df2=df2.loc[(df2['Unnamed: 5'] == "All ages") & (df2["Unnamed: 4"]=="Total")& (df2["Unnamed: 6"]=="Total")]
df2
for index, row in df2.iterrows():
    dic[row["Unnamed: 3"].lstrip("State -")[0:-5].upper()]=row["Unnamed: 7"]
dic.pop("")
#dic
dic["DELHI NCT"]=dic["NCT OF DELHI"]
dic["JAMMU AND KASHMIR"]=dic["JAMMU & KASHMIR"]
dic["SIKKIM"]=dic["IKKIM"]
dic.pop("IKKIM")
dic.pop("JAMMU & KASHMIR")
dic.pop("NCT OF DELHI")
dic



df=pd.read_csv("Scraped.csv")
x=df["5"][6]
print(x)
df
passengers=[]
for i in range(len(df)):
    temp=0
    x=df["18"][i]
    x=x.replace("EOG","")
    #x=x.strip('][').split(',')
    if(len(x)>8):
        for j in x:
            if (j.startswith("D")):
                temp+=106
            if (j.startswith("H")):
                temp+=22
            if (j.startswith("B")):
                temp+=72
            if (j.startswith("S") or j.startswith("C")):
                temp+=80
            if (j.startswith("A") or j.startswith("E")):
                temp+=54
        if temp==0:
            print(x)
            y=x
        passengers.append(temp)
passengers=list(filter(lambda a: a != 0, passengers))


def df_states(df):
    for i in range(len(df)):
        x=df["19"][i]
        x=x.strip('][').split(',')
        for j in range(1,len(x),2):
            print(x[j])
#df_states(df)




def create():
    lis=[*dic]
    df=pd.DataFrame(data=0,columns=lis, index = lis)
    return df
dfG=create()
def get_passengers(x):
    temp=0
    x=x.replace("EOG","")
    #x=x.strip('][').split(',')
    if(len(x)>8):
        for j in x:
            if (j.startswith("D")):
                temp+=106
            if (j.startswith("H")):
                temp+=22
            if (j.startswith("B")):
                temp+=72
            if (j.startswith("S") or j.startswith("C")):
                temp+=80
            if (j.startswith("A") or j.startswith("E")):
                temp+=54
    if temp>0:
        return temp
    else:
        return 1590
def get_weekdays(string):
    string=string.replace(" ","")
    #print(len(string), string)
    return len(string)
def separator(string):
    string=string[4:]
    dm,year=string.split(",")
    return dm,year[1:]

def checkruns_weight(row):      #Assumption: The end date is not in 2022. And the start date is either in 2020 or 2021
    s=row[21]
    e=row[22]
    days=0
#     TS=date(2020,5,1)
#     TE=date(2020,7,31)
#     TS=date(2020,8,1)
#     TE=date(2020,10,31)

    print(s,e)
    try:
        s,years=separator(s)
        e,yeare=separator(e)
        #
        sm,sd=s.split(" ")
        em,ed=e.split(" ")
        #
        sm=dic_month[sm]
        em=dic_month[em]
        #
        date_s=date(int(years),int(sm),int(sd))
        date_e=date(int(yeare),int(em),int(ed))
        #
        #days=date_e-date_s
        if(TS>date_s):
            CS=TS
        else:
            CS=date_s
        if(TE>date_e):
            CE=date_e
        else:
            CE=TE
        
        days=CE-CS
        
    except Exception as e:
        print(e)
        days=date(2021,6,10)-date(2021,6,10)
#         try:
#             sm,sd=s.split(" ")
#             sm=dic_month[sm]
#             date_e=date(2021,6,10)
#             date_s=date(2021,int(sm),int(sd))
#             days=date_e-date_s
#         except:
#             days=date(2021,6,10)-date(2021,6,10)


    days=days.days
    if(days<0):
        days=0
    runs=days/7*get_weekdays(row[14])*get_passengers(row[19])
    return runs
                #
#get_weekdays(df.loc[0][14])
#get_passengers(df.loc[1][19])
def separator(string):
    string=string[4:]
    dm,year=string.split(",")
    return dm,year[1:]
checkruns_weight(df.loc[0])
# Out:
# Jul 01
# ['  L', '', ' G1', ' G2', ' G3', ' G4', ' G5', ' G6', ' G7', ' G8', ' G9', 'G10', 'G11', 'G12', 'G13', 'G14', 'G15', 'G16', 'G17', 'G18', '']
# ['  L', '', 'G18', 'G17', 'G16', 'G15', 'G14', 'G13', 'G12', 'G11', 'G10', ' G9', ' G8', ' G7', ' G6', ' G5', ' G4', ' G3', ' G2', ' G1', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['  L', '', ' G1', ' G2', ' G3', ' G4', ' G5', ' G6', ' G7', ' G8', ' G9', 'G10', 'G11', 'G12', 'G13', 'G14', 'G15', 'G16', 'G17', 'G18', 'G19', '']
# ['  L', '', 'G19', 'G18', 'G17', 'G16', 'G15', 'G14', 'G13', 'G12', 'G11', 'G10', ' G9', ' G8', ' G7', ' G6', ' G5', ' G4', ' G3', ' G2', ' G1', '']
# Mon Jun 21, 2021 Thu Jul 01, 2021
# 0.0

# %%
dfG=create()
TS=date(2021,1,1)
TE=date(2021,3,1)
for index,row in df.iterrows():                 
    x=row[20]
    x=x.strip('][').split(',')
    y=[]
    for i in range(1,len(x),2):
        var=x[i].strip(" '").upper()
        if var not in y:
            y.append(var)
        else:
            pass
    print(y)
    if "TELANGANA" in y:
        if "ANDHRA PRADESH" in y:
            y.remove("TELANGANA")
        else:
            dunno=y.index("TELANGANA")
            y[dunno]="ANDHRA PRADESH"


    temp=[]
    for i in y:
        try:
            temp.append(dic[i])
        except KeyError:
            if i =="TELANGANA":
                #temp.append(dic("ANDHRA PRADESH"))

                if "ANDHRA PRADESH" in y:
                    y.remove(i)
                else:
                    dunno=y.index("TELANGANA")
                    y[dunno]="ANDHRA PRADESH"
                    #print(y)
                    temp.append(dic["ANDHRA PRADESH"])
    lis=[sum(temp[(i):len(temp)]) for i in range(len(y))]

    capacity=checkruns_weight(row)
    for i in range(len(y)-1):
        for j in range(i+1,len(y)):
            if (i==0):
                den=lis[i]-temp[i]          #Temp is the mig inside of i and and lis is from i to len(y)
                test=y[i]
                test=temp[j]
                dfG[y[i]][y[j]]+=temp[j]*capacity/den
            else:
                den2=lis[i]-temp[i]
                mult1=capacity*temp[i]/lis[i]
                mult2=temp[j]/den2
                dfG[y[i]][y[j]]+=mult1*mult2

G=nx.from_pandas_adjacency(dfG)
nx.write_gml(G,str(TS)+"_2M.gml")
nx.draw_networkx(G)
# Out:
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# Mon Jun 21, 2021 Thu Jul 01, 2021
# ['HARYANA', 'CHANDIGARH', 'DELHI NCT']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['PUNJAB', 'HARYANA', 'DELHI NCT']
# Fri Jul 02, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'PUNJAB']
# Fri Jul 02, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# Fri Jul 02, 2021 nan
# 'float' object is not subscriptable
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# Thu Jul 01, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# Sun Jul 04, 2021 nan
# 'float' object is not subscriptable
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN']
# Thu Jul 01, 2021 nan
# 'float' object is not subscriptable
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN']
# Sat Jun 26, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# Wed Jun 30, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Fri Jun 25, 2021 Sat Jul 03, 2021
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# Tue Jun 22, 2021 Wed Jul 28, 2021
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# Tue Jun 22, 2021 Wed Jul 28, 2021
# ['PUNJAB', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# Wed Jun 23, 2021 Thu Jul 01, 2021
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# Wed Oct 21, 2020 Thu Jul 01, 2021
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# Sat Jun 19, 2021 Mon Jun 28, 2021
# ['KARNATAKA']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# Sun Jun 27, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# Mon Jun 21, 2021 Tue Jul 27, 2021
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'JHARKHAND', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Fri Jun 25, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# Mon Jun 21, 2021 Tue Jul 27, 2021
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'JHARKHAND', 'BIHAR', 'ASSAM']
# Mon Jun 28, 2021 nan
# 'float' object is not subscriptable
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Tue Jun 22, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA', 'MAHARASHTRA', 'ANDHRA PRADESH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA', 'TELANGANA', 'ANDHRA PRADESH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA', 'ANDHRA PRADESH', 'TELANGANA']
# Sun Jun 20, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'KARNATAKA', 'TELANGANA', 'ANDHRA PRADESH']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA', 'ANDHRA PRADESH', 'MAHARASHTRA']
# Sun Jun 20, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'MADHYA PRADESH', 'UTTAR PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'KARNATAKA']
# Thu Jan 14, 2021 Mon Jul 26, 2021
# ['KARNATAKA', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# Mon Jan 11, 2021 Fri Jul 23, 2021
# ['MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# Mon Dec 14, 2020 Wed Nov 10, 2021
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# Fri Oct 23, 2020 Sat Jul 31, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# Sat Oct 24, 2020 Sun Aug 01, 2021
# ['MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Mon Dec 14, 2020 Wed Nov 10, 2021
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Mon Jun 14, 2021 Tue Jun 22, 2021
# ['UTTAR PRADESH']
# Tue Jun 22, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Tue Jun 22, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Tue Jun 22, 2021 nan
# 'float' object is not subscriptable
# ['HIMACHAL PRADESH', 'HARYANA']
# Tue Jun 22, 2021 nan
# 'float' object is not subscriptable
# ['HARYANA', 'HIMACHAL PRADESH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# Tue Jun 22, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND']
# Sun Jul 04, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# Mon Jul 05, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'MADHYA PRADESH', 'UTTAR PRADESH', 'MAHARASHTRA', 'CHHATTISGARH']
# Tue Jun 22, 2021 nan
# 'float' object is not subscriptable
# ['CHHATTISGARH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# Thu Jun 24, 2021 nan
# 'float' object is not subscriptable
# ['JAMMU AND KASHMIR', 'PUNJAB', 'DELHI NCT']
# Sat Jul 03, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'PUNJAB', 'JAMMU AND KASHMIR']
# Fri Jul 02, 2021 nan
# 'float' object is not subscriptable
# ['CHANDIGARH', 'HARYANA', 'DELHI NCT']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['PUNJAB']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['PUNJAB']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['HARYANA', 'CHANDIGARH', 'DELHI NCT']
# Tue Jun 22, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['PUNJAB', 'HARYANA', 'DELHI NCT']
# Fri Jul 02, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'PUNJAB']
# Thu Jul 01, 2021 nan
# 'float' object is not subscriptable
# ['HIMACHAL PRADESH', 'HARYANA']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['HARYANA', 'HIMACHAL PRADESH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['HIMACHAL PRADESH', 'HARYANA']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['HARYANA', 'HIMACHAL PRADESH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['JHARKHAND', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB']
# Mon Jun 21, 2021 Wed Jun 30, 2021
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# Sat Jun 19, 2021 Mon Jun 21, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# Fri Jun 18, 2021 Sat Jul 10, 2021
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# Wed Jun 16, 2021 Fri Jul 09, 2021
# ['KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# Sat Dec 12, 2020 Tue Nov 09, 2021
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA', 'MAHARASHTRA']
# Sun Dec 13, 2020 Mon Nov 08, 2021
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# Sat Jun 26, 2021 Mon Jul 05, 2021
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# Tue Jun 22, 2021 Wed Jun 30, 2021
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# Mon Jun 21, 2021 Tue Jun 29, 2021
# ['DELHI NCT', 'UTTAR PRADESH']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'DELHI NCT']
# Thu Jun 17, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'BIHAR']
# Fri Jul 02, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'UTTAR PRADESH']
# Thu Jul 01, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'BIHAR']
# Wed Jun 30, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'UTTAR PRADESH']
# Tue Jun 29, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'BIHAR']
# Mon Jun 28, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'UTTAR PRADESH']
# Thu Jul 01, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'BIHAR']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'UTTAR PRADESH']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GOA', 'KARNATAKA']
# Wed Jun 16, 2021 Tue Nov 09, 2021
# ['KARNATAKA', 'GOA', 'MAHARASHTRA']
# Tue Jun 15, 2021 Mon Nov 08, 2021
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'KARNATAKA', 'TAMIL NADU']
# Wed Jan 06, 2021 Fri Nov 12, 2021
# ['TAMIL NADU', 'KARNATAKA', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# Sun Jan 03, 2021 Tue Nov 09, 2021
# ['MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# Thu Dec 17, 2020 Sat Nov 06, 2021
# ['TAMIL NADU', 'KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA']
# Wed Dec 16, 2020 Thu Nov 04, 2021
# ['CHHATTISGARH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# Tue Dec 15, 2020 Thu Nov 11, 2021
# ['TAMIL NADU', 'KERALA', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'CHHATTISGARH']
# Sun Dec 13, 2020 Mon Nov 08, 2021
# ['GUJARAT', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Tue Dec 15, 2020 Thu Nov 11, 2021
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Mon Dec 14, 2020 Wed Nov 10, 2021
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'GUJARAT']
# Fri Dec 11, 2020 Mon Nov 08, 2021
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# Sat Dec 12, 2020 Mon Nov 08, 2021
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH']
# Sat Dec 12, 2020 Mon Nov 08, 2021
# ['RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Sun Oct 25, 2020 Tue Nov 09, 2021
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'RAJASTHAN']
# Thu Oct 22, 2020 Sat Nov 06, 2021
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Thu Jan 14, 2021 Wed Nov 10, 2021
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# Tue Jan 12, 2021 Sun Nov 07, 2021
# ['GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# Mon Dec 14, 2020 Wed Nov 10, 2021
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT']
# Fri Dec 11, 2020 Sun Nov 07, 2021
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA']
# Fri Dec 11, 2020 Mon Nov 08, 2021
# ['DELHI NCT', 'UTTAR PRADESH']
# Thu Jun 24, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'DELHI NCT']
# Wed Jun 23, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Fri Jun 18, 2021 Sat Jun 19, 2021
# ['MAHARASHTRA', 'GUJARAT']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'JHARKHAND']
# Tue Jun 22, 2021 Wed Jun 30, 2021
# ['JHARKHAND', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# Sat Jun 19, 2021 Mon Jun 28, 2021
# ['MAHARASHTRA']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'RAJASTHAN', 'GUJARAT']
# Tue Jun 29, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'RAJASTHAN', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# Sun Jun 27, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN', 'GUJARAT']
# Fri Jun 25, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'RAJASTHAN', 'HARYANA', 'DELHI NCT']
# Thu Jun 24, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH']
# Thu Jun 17, 2021 nan
# 'float' object is not subscriptable
# ['CHHATTISGARH', 'MAHARASHTRA', 'GUJARAT']
# Mon Jun 28, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'MAHARASHTRA', 'CHHATTISGARH']
# Sat Jun 26, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# Sat Jun 26, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# Fri Jun 25, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# Sat Jun 26, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# Fri Jun 25, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# Thu Jun 17, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Tue Jun 22, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'MAHARASHTRA']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# Wed Jun 23, 2021 Fri Jul 16, 2021
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# Sat Jun 19, 2021 Tue Jul 13, 2021
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TELANGANA']
# Sun Apr 18, 2021 Tue Jun 29, 2021
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# Sun Oct 25, 2020 Mon Jun 28, 2021
# ['HARYANA', 'PUNJAB', 'RAJASTHAN']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH', 'RAJASTHAN']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'MADHYA PRADESH']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['PUNJAB', 'HARYANA', 'RAJASTHAN']
# Sun Jun 20, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['PUNJAB', 'HARYANA', 'RAJASTHAN']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'HARYANA', 'PUNJAB']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'MADHYA PRADESH']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['PUNJAB', 'HARYANA', 'RAJASTHAN']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH', 'RAJASTHAN']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'RAJASTHAN', 'HARYANA']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['HARYANA', 'RAJASTHAN', 'UTTAR PRADESH']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'MADHYA PRADESH']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH', 'RAJASTHAN']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# Mon Jun 07, 2021 Mon Jun 21, 2021
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# Wed Jun 09, 2021 Thu Jun 17, 2021
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Sat Jun 12, 2021 Mon Jun 21, 2021
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# Thu Jun 10, 2021 Sat Jun 19, 2021
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# Thu Jun 17, 2021 Sat Jul 17, 2021
# ['BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# Wed Jun 16, 2021 Fri Jul 16, 2021
# ['MADHYA PRADESH', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# Sat Jan 16, 2021 Mon Aug 02, 2021
# ['MADHYA PRADESH', 'MAHARASHTRA']
# Mon Oct 26, 2020 Mon Aug 02, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH']
# Tue Oct 27, 2020 Tue Aug 03, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# Thu Oct 22, 2020 Sat Jul 03, 2021
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA']
# Thu Jun 17, 2021 Fri Jun 25, 2021
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL']
# Sat Jun 19, 2021 Sun Jun 27, 2021
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# Sat Jun 12, 2021 Sun Jun 20, 2021
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# Fri Jun 11, 2021 Fri Jun 18, 2021
# ['JHARKHAND', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# Wed Jun 30, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND']
# Thu Jun 17, 2021 Tue Jun 29, 2021
# ['DELHI NCT', 'UTTAR PRADESH', 'JHARKHAND']
# Wed Jun 16, 2021 Thu Jul 01, 2021
# ['JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# Wed Jun 16, 2021 Mon Jun 28, 2021
# ['CHANDIGARH', 'HARYANA', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM', 'NAGALAND']
# Wed Jul 07, 2021 nan
# 'float' object is not subscriptable
# ['JHARKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# Tue Jun 15, 2021 Wed Jun 30, 2021
# ['ASSAM', 'NAGALAND', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'HARYANA', 'CHANDIGARH']
# Mon Jul 05, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'JHARKHAND']
# Tue Jun 29, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# Mon Jun 14, 2021 Tue Jun 29, 2021
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# Tue Jun 15, 2021 Wed Jun 30, 2021
# ['ODISHA', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# Sat Jun 26, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# Sun Jun 13, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GOA']
# Sun Oct 25, 2020 Mon Nov 01, 2021
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'ODISHA', 'ANDHRA PRADESH', 'TELANGANA']
# Wed May 12, 2021 Fri Jun 18, 2021
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# Wed Jun 30, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# Sat Jul 03, 2021 nan
# 'float' object is not subscriptable
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# Sun Jun 27, 2021 nan
# 'float' object is not subscriptable
# ['HARYANA', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'BIHAR']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'JHARKHAND']
# Mon Jun 21, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'JHARKHAND']
# Sun Jun 20, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'BIHAR', 'JHARKHAND']
# Sun Jun 20, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['BIHA
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# Sat Jun 12, 2021 nan
# 'float' object is not subscriptable
# ['ODISHA', 'CHHATTISGARH', 'MADHYA PRADESH', 'RAJASTHAN']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'MADHYA PRADESH', 'CHHATTISGARH', 'ODISHA']
# Sun Jun 13, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Sun Jun 13, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TELANGANA']
# Wed Jun 09, 2021 Thu Jul 01, 2021
# ['RAJASTHAN']
# Sun Jun 13, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Sat Jun 12, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'HARYANA']
# Thu Jun 10, 2021 nan
# 'float' object is not subscriptable
# ['HARYANA', 'RAJASTHAN']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['HARYANA', 'RAJASTHAN']
# Thu Jun 10, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'HARYANA']
# Wed Jun 09, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'MADHYA PRADESH']
# Sat Jun 12, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH', 'UTTAR PRADESH']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH']
# Thu Jun 10, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'UTTAR PRADESH']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'RAJASTHAN']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'HIMACHAL PRADESH']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'HARYANA', 'DELHI NCT']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['PUNJAB', 'HARYANA', 'DELHI NCT']
# Thu Jun 17, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'PUNJAB']
# Thu Jun 17, 2021 nan
# 'float' object is not subscriptable
# ['HARYANA', 'PUNJAB', 'RAJASTHAN']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['HIMACHAL PRADESH', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['JAMMU AND KASHMIR', 'PUNJAB', 'CHANDIGARH', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'HARYANA', 'CHANDIGARH', 'PUNJAB', 'JAMMU AND KASHMIR']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['HIMACHAL PRADESH', 'PUNJAB', 'CHANDIGARH', 'HARYANA', 'DELHI NCT']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH', 'PUNJAB', 'HIMACHAL PRADESH']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'DELHI NCT']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['GOA', 'MAHARASHTRA', 'GUJARAT', 'RAJASTHAN', 'DELHI NCT']
# Sun Jun 20, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'GOA']
# Fri Jun 18, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT', 'RAJASTHAN']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'UTTAR PRADESH', 'DELHI NCT', 'UTTARAKHAND']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'MADHYA PRADESH']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'UTTAR PRADESH']
# Thu Jun 10, 2021 nan
# 'float' object is not subscriptable
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'UTTAR PRADESH']
# Tue Jun 15, 2021 Wed Jun 23, 2021
# ['MADHYA PRADESH', 'UTTAR PRADESH']
# Sat Jun 12, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# Mon Jun 14, 2021 Tue Jun 22, 2021
# ['RAJASTHAN', 'UTTAR PRADESH']
# Sat Jun 12, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'DELHI NCT']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'BIHAR']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'UTTAR PRADESH']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'RAJASTHAN']
# Sat Jun 12, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'UTTARAKHAND']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Thu Jun 17, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Wed Jun 16, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Thu Jun 10, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'BIHAR']
# Thu Jun 10, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'UTTAR PRADESH']
# Thu Jun 10, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Tue Jun 15, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Mon Jun 14, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Sun Jun 13, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# Sun Jun 13, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# Thu Jun 10, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# Sat Jun 12, 2021 Mon Jun 28, 2021
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'GUJARAT']
# Thu Jun 10, 2021 Sat Jun 26, 2021
# ['BIHAR', 'JHARKHAND', 'WEST BENGAL']
# Tue Jun 15, 2021 Wed Jun 30, 2021
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR']
# Wed Jun 16, 2021 Wed Jun 30, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# Tue Jun 15, 2021 Sat Jul 03, 2021
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# Sun Jun 13, 2021 Thu Jul 01, 2021
# ['WEST BENGAL', 'BIHAR']
# Sat Jun 12, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'WEST BENGAL']
# Thu Jun 10, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# Fri Jun 11, 2021 Fri Jul 02, 2021
# ['BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# Thu Jun 10, 2021 Thu Jul 01, 2021
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA', 'GUJARAT']
# Mon Jun 07, 2021 Wed Jun 30, 2021
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# Thu Jul 08, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# Tue Jul 06, 2021 nan
# 'float' object is not subscriptable
# ['PUNJAB', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# Fri Jun 04, 2021 Sun Jun 27, 2021
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA']
# Thu Jun 10, 2021 Sat Jun 26, 2021
# ['JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA']
# Wed Jun 09, 2021 Fri Jun 25, 2021
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# Sun Jun 13, 2021 Mon Jun 28, 2021
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL']
# Sat Jun 12, 2021 Mon Jun 28, 2021
# ['GUJARAT', 'MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL']
# Wed Jun 09, 2021 Fri Jul 02, 2021
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# Sat Jun 12, 2021 Sun Jun 27, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# Sun Jun 13, 2021 Tue Jun 29, 2021
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'JHARKHAND']
# Fri Oct 23, 2020 Wed Jun 30, 2021
# ['JHARKHAND', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# Tue Oct 20, 2020 Tue Jun 29, 2021
# ['DELHI NCT', 'UTTAR PRADESH']
# Sat Jun 12, 2021 Sat Jun 19, 2021
# ['UTTAR PRADESH', 'DELHI NCT']
# Fri Jun 11, 2021 Sat Jun 19, 2021
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH']
# Mon Jun 07, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'RAJASTHAN']
# Mon Jun 07, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'UTTAR PRADESH']
# Mon Jun 07, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'RAJASTHAN']
# Mon Jun 07, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Mon Jun 07, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH']
# Mon Jun 07, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH']
# Mon Jun 07, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH']
# Mon Jun 07, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH']
# Sun Jun 06, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH']
# Sun Jun 06, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH']
# Mon Jun 07, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH']
# Tue Jun 08, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# Sat Jun 05, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH']
# Sun Jun 06, 2021 nan
# 'float' object is not subscriptable
# ['JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA']
# Fri Jun 11, 2021 Sat Jun 26, 2021
# ['BIHAR', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA', 'TELANGANA']
# Tue Jun 08, 2021 Thu Jul 01, 2021
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# Sun Jun 13, 2021 Mon Jun 28, 2021
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL']
# Fri Jun 11, 2021 Sat Jun 26, 2021
# ['TELANGANA', 'MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'BIHAR']
# Sun Jun 06, 2021 Tue Jun 29, 2021
# ['DELHI NCT', 'UTTAR PRADESH']
# Tue Jun 08, 2021 Wed Jun 30, 2021
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA']
# Wed Jun 09, 2021 Thu Jun 24, 2021
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH', 'JHARKHAND', 'WEST BENGAL']
# Fri Jun 11, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'JHARKHAND', 'UTTAR PRADESH', 'DELHI NCT', 'HARYANA', 'RAJASTHAN']
# Wed Jun 09, 2021 nan
# 'float' object is not subscriptable
# ['BIHAR', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA', 'TELANGANA']
# Mon May 10, 2021 Tue Jun 29, 2021
# ['UTTAR PRADESH', 'DELHI NCT']
# Mon Jun 07, 2021 Tue Jun 29, 2021
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# Mon Jan 18, 2021 Wed Jun 30, 2021
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# Sun Jun 06, 2021 Mon Jun 28, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# Mon Jun 07, 2021 Tue Jun 29, 2021
# ['TELANGANA', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# Sun Jun 06, 2021 Tue Jun 15, 2021
# ['ODISHA', 'WEST BENGAL', 'JHARKHAND', 'CHHATTISGARH', 'MADHYA PRADESH', 'UTTAR PRADESH', 'RAJASTHAN', 'HARYANA', 'DELHI NCT', 'UTTARAKHAND']
# Wed Jan 27, 2021 Fri Jul 02, 2021
# ['TELANGANA', 'MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHA
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# Tue May 11, 2021 Thu May 27, 2021
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH']
# Thu May 13, 2021 Sat May 29, 2021
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# Mon May 10, 2021 Tue May 25, 2021
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# Wed May 12, 2021 Thu May 27, 2021
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# Fri May 14, 2021 Sat May 29, 2021
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Wed May 12, 2021 Sun May 30, 2021
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# Wed May 12, 2021 Thu May 27, 2021
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# Mon May 10, 2021 Sat May 29, 2021
# ['WEST BENGAL']
# Mon Dec 28, 2020 Fri May 21, 2021
# ['WEST BENGAL']
# Mon Dec 28, 2020 Fri May 21, 2021
# ['WEST BENGAL']
# Sat Dec 12, 2020 Fri May 21, 2021
# ['WEST BENGAL']
# Sat Dec 12, 2020 Fri May 21, 2021
# ['WEST BENGAL', 'JHARKHAND']
# Fri Dec 11, 2020 Fri May 21, 2021
# ['WEST BENGAL', 'JHARKHAND']
# Thu Dec 10, 2020 Fri May 21, 2021
# ['BIHAR', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA', 'TELANGANA']
# Tue May 18, 2021 Thu Jun 03, 2021
# ['JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA', 'GUJARAT']
# Sat Apr 17, 2021 Mon May 31, 2021
# ['CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL', 'BIHAR']
# Thu Nov 12, 2020 Sat Jul 03, 2021
# ['BIHAR', 'JHARKHAND', 'WEST BENGAL', 'ODISHA', 'CHHATTISGARH']
# Tue Nov 10, 2020 Thu Jul 01, 2021
# ['WEST BENGAL']
# Thu Dec 10, 2020 Thu May 20, 2021
# ['WEST BENGAL']
# Wed Dec 09, 2020 Thu May 20, 2021
# ['WEST BENGAL']
# Thu Jan 21, 2021 Thu May 20, 2021
# ['WEST BENGAL']
# Thu Jan 21, 2021 Thu May 20, 2021
# ['GUJARAT', 'MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# Thu Apr 15, 2021 Sat May 29, 2021
# ['WEST BENGAL', 'BIHAR']
# Sat Jun 19, 2021 nan
# 'float' object is not subscriptable
# ['ODISHA', 'WEST BENGAL']
# Tue Jun 02, 2020 Fri May 21, 2021
# ['WEST BENGAL', 'ODISHA']
# Mon Jun 01, 2020 Thu May 20, 2021
# ['MADHYA PRADESH', 'MAHARASHTRA']
# Fri Feb 19, 2021 Sat May 22, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH']
# Thu Feb 18, 2021 Fri May 21, 2021
# ['MAHARASHTRA']
# Thu Jan 21, 2021 Thu May 20, 2021
# ['RAJASTHAN', 'HARYANA', 'PUNJAB']
# Thu Oct 22, 2020 Sun Jun 27, 2021
# ['WEST BENGAL']
# Sun Feb 28, 2021 Wed May 19, 2021
# ['WEST BENGAL']
# Sun Feb 28, 2021 Wed May 19, 2021
# ['MADHYA PRADESH', 'RAJASTHAN']
# Wed Dec 30, 2020 Wed May 19, 2021
# ['RAJASTHAN', 'MADHYA PRADESH']
# Tue Dec 29, 2020 Tue May 18, 2021
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# Mon May 24, 2021 Wed Jun 30, 2021
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# Sat May 22, 2021 Mon Jun 28, 2021
# ['HARYANA', 'RAJASTHAN']
# Sat Apr 10, 2021 Sun May 16, 2021
# ['RAJASTHAN', 'HARYANA']
# Sat Apr 10, 2021 Sat May 15, 2021
# ['TRIPURA', 'ASSAM', 'WEST BENGAL', 'BIHAR', 'JHARKHAND']
# Tue Oct 27, 2020 Fri Jul 02, 2021
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'GUJARAT']
# Tue Oct 27, 2020 Thu Jul 01, 2021
# ['MAHARASHTRA']
# Mon Oct 12, 2020 Mon May 17, 2021
# ['MAHARASHTRA']
# Tue Oct 13, 2020 Tue May 18, 2021
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# ...
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'KARNATAKA', 'TELANGANA', 'MAHARASHTRA']
# Sat Apr 03, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'TELANGANA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL']
# Mon Apr 05, 2021 nan
# 'float' object is not subscriptable
# ['ODISHA', 'JHARKHAND', 'BIHAR']
# nan nan
# 'float' object is not subscriptable
# ['BIHAR', 'JHARKHAND', 'ODISHA']
# Fri Feb 26, 2021 nan
# 'float' object is not subscriptable
# ['TELANGANA', 'ANDHRA PRADESH']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'TELANGANA']
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'TELANGANA']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'TELANGANA']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['TELANGANA', 'ANDHRA PRADESH']
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'TELANGANA', 'KARNATAKA', 'MAHARASHTRA']
# Tue Apr 06, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'KARNATAKA', 'TELANGANA', 'ANDHRA PRADESH']
# Wed Apr 07, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# nan nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# nan nan
# 'float' object is not subscriptable
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT', 'RAJASTHAN', 'DELHI NCT']
# Mon Mar 01, 2021 Wed Mar 03, 2021
# ['ANDHRA PRADESH', 'KARNATAKA', 'GOA']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['TELANGANA', 'ANDHRA PRADESH', 'KARNATAKA', 'GOA']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['TELANGANA', 'ANDHRA PRADESH']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'TELANGANA']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'TAMIL NADU']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH']
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['TELANGANA', 'ANDHRA PRADESH']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'TELANGANA']
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['TELANGANA', 'ANDHRA PRADESH']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'TELANGANA']
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH']
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'KARNATAKA', 'TELANGANA', 'MAHARASHTRA']
# Tue Apr 06, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'TELANGANA', 'KARNATAKA', 'ANDHRA PRADESH']
# Wed Apr 07, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Wed Mar 10, 2021 Fri Apr 30, 2021
# ['UTTAR PRADESH', 'BIHAR']
# Thu May 13, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH']
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['KERALA', 'TAMIL NADU']
# Sat Apr 03, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'KERALA']
# Sun Apr 04, 2021 nan
# 'float' object is not subscriptable
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'DELHI NCT']
# Wed Apr 07, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA', 'KERALA', 'TAMIL NADU']
# Thu Apr 08, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# Fri Apr 09, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'KERALA', 'KARNATAKA']
# Fri Apr 09, 2021 nan
# 'float' object is not subscriptable
# ['KERALA', 'TAMIL NADU', 'KARNATAKA']
# Mon Apr 05, 2021 Thu Apr 29, 2021
# ['MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Wed Mar 17, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# Sun Mar 21, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# Tue Mar 23, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA', 'MAHARASHTRA']
# Fri Mar 19, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# Tue Mar 16, 2021 Wed May 05, 2021
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA']
# Wed Mar 17, 2021 Thu May 06, 2021
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# Mon Mar 22, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN', 'HARYANA', 'DELHI NCT']
# Tue Mar 23, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'MAHARASHTRA']
# Fri Mar 19, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GUJARAT']
# Thu Mar 18, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN']
# Sun Mar 21, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Tue Mar 23, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH']
# Thu Mar 18, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Fri Mar 19, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA', 'KARNATAKA', 'TELANGANA']
# Sat Mar 20, 2021 Sun May 02, 2021
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA']
# Sun Apr 04, 2021 nan
# 'float' object is not subscriptable
# ['TELANGANA']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'TAMIL NADU']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH']
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH']
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# Thu Mar 25, 2021 Fri Mar 26, 2021
# ['WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# Wed Mar 24, 2021 Fri Mar 26, 2021
# ['PUNJAB', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND']
# Tue Apr 06, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB']
# Mon Apr 05, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# Mon Apr 05, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'RAJASTHAN']
# Fri Apr 02, 2021 nan
# 'float' object is not subscriptable
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT', 'RAJASTHAN', 'DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# Fri Apr 16, 2021 nan
# 'float' object is not subscriptable
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# Mon Apr 19, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU']
# Sat Apr 10, 2021 Wed Apr 28, 2021
# ['TAMIL NADU']
# Sat Apr 10, 2021 Wed Apr 28, 2021
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA']
# Sun Apr 11, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# Mon Apr 12, 2021 nan
# 'float' object is not subscriptable
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# Thu Apr 01, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Thu Apr 22, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# Tue Apr 20, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA']
# Sat Apr 10, 2021 Tue Apr 27, 2021
# ['KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Sat Apr 10, 2021 Tue Apr 27, 2021
# ['PUDUCHERRY', 'TAMIL NADU', 'KERALA', 'KARNATAKA']
# Thu Apr 15, 2021 nan
# 'float' object is not subscriptable
# ['PUDUCHERRY', 'TAMIL NADU']
# Sun Apr 11, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'PUDUCHERRY']
# Mon Apr 12, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU']
# Mon Apr 26, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU']
# Sun Apr 18, 2021 nan
# 'float' object is not subscriptable
# ['ODISHA']
# Wed Apr 14, 2021 nan
# 'float' object is not subscriptable
# ['ODISHA']
# Tue Apr 13, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# Thu Apr 29, 2021 Sat May 01, 2021
# ['RAJASTHAN', 'GUJARAT']
# Sat Apr 10, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'RAJASTHAN']
# Sun Apr 11, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'GUJARAT']
# Sat Apr 10, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'RAJASTHAN']
# Sat Apr 10, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'HARYANA']
# Sun Apr 11, 2021 Mon Apr 26, 2021
# ['HARYANA', 'RAJASTHAN']
# Sun Apr 11, 2021 Mon Apr 26, 2021
# ['HARYANA', 'RAJASTHAN']
# Sun Apr 11, 2021 Tue Apr 27, 2021
# ['RAJASTHAN', 'PUNJAB']
# Sat Apr 10, 2021 Mon Apr 26, 2021
# ['RAJASTHAN', 'HARYANA']
# Tue Apr 13, 2021 nan
# 'float' object is not subscriptable
# ['HARYANA', 'RAJASTHAN']
# Tue Apr 13, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'PUNJAB']
# Sat Apr 10, 2021 Mon Apr 26, 2021
# ['RAJASTHAN', 'HARYANA']
# Sun Apr 11, 2021 Mon Apr 26, 2021
# ['PUNJAB', 'RAJASTHAN']
# Sat Apr 10, 2021 Mon Apr 26, 2021
# ['GUJARAT', 'RAJASTHAN']
# Sun Apr 11, 2021 Mon May 03, 2021
# ['GUJARAT', 'MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Sun Apr 25, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU']
# Tue Apr 27, 2021 nan
# 'float' object is not subscriptable
# ['ANDHRA PRADESH', 'TAMIL NADU']
# Fri Apr 23, 2021 nan
# 'float' object is not subscriptable
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# Sat Apr 24, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH']
# Thu Apr 22, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT']
# Tue Apr 27, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# Fri Apr 30, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH', 'MAHARASHTRA', 'GUJARAT']
# Mon Apr 12, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'MAHARASHTRA', 'MADHYA PRADESH']
# Sun Apr 11, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'MADHYA PRADESH', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL']
# Sat Apr 10, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MADHYA PRADESH', 'RAJASTHAN']
# Sun Apr 11, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'RAJASTHAN', 'UTTAR PRADESH']
# Thu Apr 15, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'RAJASTHAN', 'UTTAR PRADESH']
# Mon Apr 12, 2021 nan
# 'float' object is not subscriptable
# ['GUJARAT', 'RAJASTHAN', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH']
# Thu Apr 15, 2021 nan
# 'float' object is not subscriptable
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# Tue Apr 27, 2021 nan
# 'float' object is not subscriptable
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# Fri Apr 30, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'RAJASTHAN', 'HARYANA', 'DELHI NCT', 'PUNJAB', 'JAMMU AND KASHMIR']
# Mon Apr 12, 2021 nan
# 'float' object is not subscriptable
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Thu Apr 15, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Sun Apr 11, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Mon Apr 12, 2021 Mon Apr 26, 2021
# ['RAJASTHAN']
# Mon Apr 12, 2021 Mon Apr 26, 2021
# ['RAJASTHAN']
# Mon Apr 12, 2021 Mon Apr 26, 2021
# ['RAJASTHAN']
# Mon Apr 12, 2021 Mon Apr 26, 2021
# ['KARNATAKA']
# Sat Apr 10, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA']
# Thu Apr 15, 2021 Fri Apr 30, 2021
# ['KARNATAKA']
# Tue Apr 13, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Tue Apr 13, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Mon Apr 12, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA']
# Mon Apr 12, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Sat Apr 10, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Sun Apr 11, 2021 nan
# 'float' object is not subscriptable
# ['MADHYA PRADESH']
# Thu Apr 08, 2021 Mon Apr 19, 2021
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# Wed Apr 14, 2021 Fri May 14, 2021
# ['PUDUCHERRY', 'TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA', 'MAHARASHTRA']
# Mon Apr 19, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU', 'PUDUCHERRY']
# Sat Apr 17, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN']
# Sat Apr 10, 2021 Mon Apr 26, 2021
# ['RAJASTHAN']
# Sat Apr 10, 2021 Mon Apr 26, 2021
# ['JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# Thu Apr 08, 2021 Fri Apr 09, 2021
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# Mon Apr 12, 2021 Wed May 19, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# Fri Apr 09, 2021 Mon Apr 12, 2021
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Tue Apr 13, 2021 Thu Jun 03, 2021
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Wed Apr 14, 2021 Thu May 20, 2021
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# Wed Apr 21, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Fri Apr 23, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# Tue Apr 27, 2021 nan
# 'float' object is not subscriptable
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'RAJASTHAN']
# Mon May 03, 2021 nan
# 'float' object is not subscriptable
# ['RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# Thu May 06, 2021 nan
# 'float' object is not subscriptable
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# Tue Apr 13, 2021 Sun May 02, 2021
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# Thu Apr 15, 2021 Fri Apr 16, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# Fri Apr 16, 2021 Sat Apr 17, 2021
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# Sat Apr 17, 2021 Wed Apr 28, 2021
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# Fri Apr 23, 2021 Sun Apr 25, 2021
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# Fri Apr 23, 2021 Sun Apr 25, 2021
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# Thu Apr 22, 2021 nan
# 'float' object is not subscriptable
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# Tue Apr 27, 2021 nan
# 'float' object is not subscriptable
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# Fri Apr 23, 2021 Sun Apr 25, 2021
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# ANDHRA PRADESH                   0       6087          28681   27566
# KARNATAKA                        0          0           8565    3448
# GOA                              0          0             40       0
# LAKSHADWEEP                      0          0              0       0
# KERALA                           0          0            387    1512
# TAMIL NADU                       0       5775           8567    8830
# PUDUCHERRY                       0          0              0       0
# ANDAMAN & NICOBAR ISLANDS        0          0              0       0
# DELHI NCT                   301224     141561         494784   37091
# JAMMU AND KASHMIR            27327       8389          18473    1390
# SIKKIM                           0          0              0       0
#
#                            ARUNACHAL PRADESH  NAGALAND  ...  KARNATAKA  \
# HIMACHAL PRADESH                           0         0  ...          0
# PUNJAB                                     0         0  ...          0
# CHANDIGARH                                 0         0  ...          0
# UTTARAKHAND                                0         0  ...          0
# HARYANA                                    0         0  ...          0
# RAJASTHAN                                  0         0  ...          0
# UTTAR PRADESH                              0         1  ...      28821
# BIHAR                                      0         0  ...       2674
# ARUNACHAL PRADESH                          0         0  ...          0
# NAGALAND                                   0         0  ...          0
# MANIPUR                                    0         0  ...          0
# MIZORAM                                    0         0  ...          0
# TRIPURA                                    0         0  ...          0
# MEGHALAYA                                  0         0  ...          0
# ASSAM                                      0         0  ...          0
# WEST BENGAL                                0         0  ...      25200
# JHARKHAND                                  0         0  ...       2927
# ODISHA                                     0         0  ...      19203
# CHHATTISGARH                               0         0  ...          0
# MADHYA PRADESH                             0         0  ...      16451
# GUJARAT                                    0         0  ...       2623
# DAMAN & DIU                                0         0  ...          0
# DADRA & NAGAR HAVELI                       0         0  ...          0
# MAHARASHTRA                                0         0  ...     150829
# ANDHRA PRADESH                             0         0  ...     310891
# KARNATAKA                                  0         0  ...          0
# GOA                                        0         0  ...      12628
# LAKSHADWEEP                                0         0  ...          0
# KERALA                                     0         0  ...      83759
# TAMIL NADU                                 0         0  ...     303847
# PUDUCHERRY                                 0         0  ...          0
# ANDAMAN & NICOBAR ISLANDS                  0         0  ...          0
# DELHI NCT                                  0         0  ...       3549
# JAMMU AND KASHMIR                          0         0  ...          0
# SIKKIM                                     0         0  ...          0
#
#                               GOA  LAKSHADWEEP  KERALA  TAMIL NADU  \
# HIMACHAL PRADESH                0            0       0           0
# PUNJAB                          0            0       0           0
# CHANDIGARH                      0            0       0           0
# UTTARAKHAND                     0            0       0           0
# HARYANA                         0            0       0           0
# RAJASTHAN                       0            0       0        4235
# UTTAR PRADESH                3424            0    3580       13169
# BIHAR                           0            0    1716        2311
# ARUNACHAL PRADESH               0            0       0           0
# NAGALAND                        0            0       0           0
# MANIPUR                         0            0       0           0
# MIZORAM                         0            0       0           0
# TRIPURA                         0            0       0           0
# MEGHALAYA                       0            0       0           0
# ASSAM                           0            0       0           0
# WEST BENGAL                     0            0       0       30353
# JHARKHAND                       0            0       0        1661
# ODISHA                          0            0       0       32228
# CHHATTISGARH                    0            0     171         988
# MADHYA PRADESH               1922            0    4437       11168
# GUJARAT                       377            0    8751        6747
# DAMAN & DIU                     0            0       0           0
# DADRA & NAGAR HAVELI            0            0       0           0
# MAHARASHTRA                266755            0   32374       68178
