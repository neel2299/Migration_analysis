# %%
import pandas as pd
import numpy as np
#arr=pd.DataFrame(pd.read_csv('.csv'))
arr=pd.read_excel("19.xls")
Dat_f=arr
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %%
def list_maker():
    lis=[]
    init=2
    cyc=5
    while(init<130):
        for i in range(0,5):
            lis.append("Unnamed: "+str(init))
            init=init+2
        init=init+1
    lis.pop()
    lis.pop()
    lis.pop()
    return lis
def list_maker2():
    lis=["Unnamed: 1","Unnamed: 3","Unnamed: 5","Unnamed: 7","Unnamed: 122","Unnamed: 126","Unnamed: 127","Unnamed: 128","Unnamed: 129"]
    for i in range(1,12):
        lis.append("Unnamed: "+str(i*11))
    return lis

# %%
#list_maker()

# %%
lis=range(0,10)
Dat_f.drop(lis, axis=0, inplace=True)    #clearing first 6 rows 
lis=list_maker()
Dat_f.fillna(0,inplace=True)
Dat_f.drop(lis, axis=1, inplace=True)    #clearing error columns
lis=list_maker2()
lis.append("Table with row headers in column A, L, W, AH, AS, BD, BO, BZ, CK, CV, and DG, and column headers in rows 6 through 8 and 45 through 47.")
Dat_f.drop(lis, axis=1, inplace=True)    #clearing visibility label columns
lis=[15,21,27,33,39,42,43,44,45,46,52,58,64,70,75,78,79,80,81,82,83,84,85]
Dat_f.drop(lis, axis=0, inplace=True)    #clearing misc rows
try:
    Dat_f.drop([77],axis=0,inplace=True)
except:
    print("🤞")

# %% [markdown]
# ############################################## SHEET 9 ###################################################
#
# lis=range(0,8)
# Dat_f.drop(lis, axis=0, inplace=True)    #clearing first 6 rows
# lis=[]
# header="Table with row headers in column A, L, W, AH, AS, BD, BO, BZ, CK, CV, and DG, and column headers in rows 6 through 8 and 46 through 48."
# lis.append(header)
# for i in range(1,10):
#     lis.append(header+'.'+str(i))
# Dat_f.drop(lis,axis=1,inplace=True)      #clearing header columns
# lis=list_maker()
# Dat_f.drop(lis, axis=1, inplace=True)    #clearing error columns
# lis=[13,19,25,31,37,43,44,45,46,47,53,59,65,71,74,75,76,77]
# Dat_f.drop(lis, axis=0, inplace=True)    #clearing misc rows
# header="Dataset: 2007-2009 American Community Survey 3-Year Estimates"
# Dat_f.drop(header,axis=1,inplace=True)

# %%
def clean2(df):                              #CAN CALL Multiple times
    arr=df.to_numpy()
    np.fill_diagonal(arr, 0)
    for i in range(0,52):
        for j in range(0,52):
            arr[i,j]=int(str(arr[i,j]).replace(',', ''))
    #label=range(0,52)
    label=["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","District of Columbia","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Puerto Rico","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]
    return pd.DataFrame(arr,index=label, columns=label)
    
def dat_conv(df):
    for column in df.columns:
        df[column] = df[column].astype(str).astype(int)

# %%
Dat_f=clean2(Dat_f)

# %%
Dat_f.to_csv('Cleansheet19.csv')

# %%
Dat_f
# Out:
#                      Alabama Alaska Arizona Arkansas California Colorado  \
# Alabama                    0   1105     904      813       3690     2042
# Alaska                   260      0     886       12       2547      685
# Arizona                 1750   1561       0     1022      59713    14684
# Arkansas                 636     98     692        0       4967     1585
# California              3310   5064   28226     3104          0    15085
# Colorado                3422    862   10616     1022      29350        0
# Connecticut              248    220     441        0       4049     1165
# Delaware                   0    294       0        0        161      530
# District of Columbia     462    338     291        0       3437      870
# Florida                15153   4906    7054     3544      28628    13656
# Georgia                14169   1378    2362     3322      15437     2904
# Hawaii                   502    907     803      169      10954     2190
# ...
